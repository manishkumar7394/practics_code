# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("/Users/manish/Downloads/titanic.csv")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
cat_count = df['embark_town'].value_counts()

# %%
cat_count
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# # I can find top emabark_town

# %%
x_bar = cat_count.index
x_bar
# Out:
# Index(['Southampton', 'Cherbourg', 'Queenstown'], dtype='object', name='embark_town')

# %%
y_bar  = cat_count.values
y_bar
# Out:
# array([644, 168,  77])

# %%
plt.bar(x_bar,y_bar)
# Out:
# <BarContainer object of 3 artists>
